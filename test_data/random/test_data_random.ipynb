# %%
import random
import csv

def assign_students_to_projects(num_projects=201, num_choices=3, max_students_range=5):
    # Define project names and capacities
    project_names = ['p{}'.format(i) for i in range(1, num_projects + 1)]
    max_students = [random.randint(1, max_students_range) for _ in range(num_projects)]
    students = ['s{}'.format(i) for i in range(1, num_projects + 1)]

    # Generate student preference data
    student_preferences = {student: random.sample(project_names, num_choices) for student in students}

    # Define the project data with initial capacities and empty slots for student assignments
    project_data = {project: {'max_students': cap, 'assigned_students': []} for project, cap in zip(project_names, max_students)}

    # Create a shuffled list of all student preferences
    all_preferences = []
    for student, preferences in student_preferences.items():
        for preference in preferences:
            all_preferences.append((student, preference))
    random.shuffle(all_preferences)  # Shuffle to ensure fair assignment chances

    # Function to assign students to their preferred projects without duplications within the same project
    def initial_assignment():
        assigned_students = set()  # Keep track of which students have been assigned
        for student, preference in all_preferences:
            if len(project_data[preference]['assigned_students']) < project_data[preference]['max_students'] and student not in assigned_students:
                project_data[preference]['assigned_students'].append(student)
                assigned_students.add(student)

    # Function to fill under-capacity projects with any available students
    def fill_under_capacity_projects():
        for project, details in project_data.items():
            while len(details['assigned_students']) < details['max_students']:
                possible_students = set(students) - set(details['assigned_students'])
                if not possible_students:
                    break
                student = random.choice(list(possible_students))
                details['assigned_students'].append(student)

    # Assign students to projects
    initial_assignment()
    fill_under_capacity_projects()

    # Save student preferences to CSV
    with open('student_preferences.csv', 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        # Write column names for preferences
        pref_columns = ['{}st_choice'.format(i+1) for i in range(num_choices)]
        writer.writerow(['student_names'] + pref_columns)
        # Write student preferences
        for student, prefs in student_preferences.items():
            row = [student] + prefs
            writer.writerow(row)

    # Save project assignments to CSV
    with open('project_assignments.csv', 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['project_name', 'max_students'] + ['{}st_choice'.format(i+1) for i in range(num_choices)])
        for project, details in project_data.items():
            # Separate assigned students into multiple columns for each choice
            assigned_students = details['assigned_students']
            row = [project, details['max_students']]
            for i in range(num_choices):
                if i < len(assigned_students):
                    row.append(assigned_students[i])
                else:
                    row.append("")  # Fill empty if no more assigned students
            writer.writerow(row)

    # Read CSV and extract column names
    with open('student_preferences.csv', newline='') as csvfile:
        reader = csv.reader(csvfile)
        student_names = next(reader)

    # Return the generated data and extracted column names
    return student_preferences, project_data, student_names

# Example usage:
assign_students_to_projects(num_projects=200, num_choices=5, max_students_range=5)
# Out:
# ({'s1': ['p102', 'p12', 'p121', 'p144', 'p125'],
#   's2': ['p119', 'p108', 'p107', 'p92', 'p100'],
#   's3': ['p48', 'p169', 'p124', 'p117', 'p198'],
#   's4': ['p92', 'p75', 'p42', 'p112', 'p165'],
#   's5': ['p46', 'p184', 'p188', 'p77', 'p159'],
#   's6': ['p85', 'p20', 'p133', 'p30', 'p38'],
#   's7': ['p46', 'p153', 'p25', 'p134', 'p45'],
#   's8': ['p7', 'p64', 'p46', 'p132', 'p94'],
#   's9': ['p101', 'p146', 'p166', 'p90', 'p34'],
#   's10': ['p166', 'p47', 'p13', 'p34', 'p25'],
#   's11': ['p103', 'p118', 'p35', 'p154', 'p43'],
#   's12': ['p85', 'p26', 'p89', 'p144', 'p129'],
#   's13': ['p119', 'p34', 'p152', 'p28', 'p182'],
#   's14': ['p89', 'p159', 'p169', 'p186', 'p109'],
#   's15': ['p6', 'p195', 'p96', 'p104', 'p92'],
#   's16': ['p119', 'p200', 'p32', 'p108', 'p160'],
#   's17': ['p183', 'p42', 'p51', 'p114', 'p77'],
#   's18': ['p109', 'p59', 'p66', 'p155', 'p25'],
#   's19': ['p36', 'p38', 'p79', 'p106', 'p30'],
#   's20': ['p166', 'p198', 'p99', 'p156', 'p148'],
#   's21': ['p104', 'p163', 'p53', 'p57', 'p79'],
#   's22': ['p105', 'p157', 'p148', 'p164', 'p95'],
#   's23': ['p143', 'p137', 'p108', 'p74', 'p45'],
#   's24': ['p154', 'p24', 'p39', 'p150', 'p6'],
#   's25': ['p130', 'p102', 'p59', 'p16', 'p119'],
#   's26': ['p161', 'p91', 'p7', 'p136', 'p169'],
#   's27': ['p38', 'p105', 'p182', 'p113', 'p155'],
#   's28': ['p14', 'p53', 'p170', 'p155', 'p130'],
#   's29': ['p129', 'p134', 'p108', 'p66', 'p189'],
#   's30': ['p93', 'p72', 'p56', 'p125', 'p4'],
#   's31': ['p53', 'p174', 'p100', 'p131', 'p22'],
#   's32': ['p135', 'p32', 'p145', 'p191', 'p12'],
#   's33': ['p138', 'p62', 'p176', 'p24', 'p76'],
#   's34': ['p199', 'p42', 'p41', 'p123', 'p54'],
#   's35': ['p145', 'p24', 'p113', 'p150', 'p51'],
#   's36': ['p134', 'p11', 'p158', 'p185', 'p88'],
#   's37': ['p75', 'p25', 'p125', 'p136', 'p67'],
#   's38': ['p170', 'p116', 'p124', 'p176', 'p183'],
#   's39': ['p27', 'p61', 'p50', 'p89', 'p166'],
#   's40': ['p80', 'p99', 'p180', 'p152', 'p21'],
#   's41': ['p139', 'p17', 'p102', 'p26', 'p15'],
#   's42': ['p200', 'p156', 'p121', 'p125', 'p167'],
#   's43': ['p11', 'p99', 'p69', 'p72', 'p76'],
#   's44': ['p27', 'p134', 'p180', 'p151', 'p131'],
#   's45': ['p16', 'p40', 'p154', 'p180', 'p179'],
#   's46': ['p39', 'p129', 'p136', 'p70', 'p166'],
#   's47': ['p177', 'p64', 'p172', 'p139', 'p118'],
#   's48': ['p99', 'p10', 'p79', 'p128', 'p109'],
#   's49': ['p56', 'p3', 'p124', 'p147', 'p76'],
#   's50': ['p199', 'p91', 'p144', 'p113', 'p2'],
#   's51': ['p25', 'p3', 'p103', 'p11', 'p152'],
#   's52': ['p167', 'p166', 'p114', 'p192', 'p31'],
#   's53': ['p185', 'p158', 'p112', 'p7', 'p85'],
#   's54': ['p1', 'p143', 'p129', 'p40', 'p152'],
#   's55': ['p61', 'p164', 'p147', 'p149', 'p27'],
#   's56': ['p66', 'p29', 'p55', 'p157', 'p48'],
#   's57': ['p34', 'p28', 'p177', 'p122', 'p33'],
#   's58': ['p137', 'p85', 'p169', 'p102', 'p173'],
#   's59': ['p113', 'p125', 'p112', 'p166', 'p172'],
#   's60': ['p53', 'p36', 'p176', 'p41', 'p61'],
#   's61': ['p106', 'p81', 'p35', 'p173', 'p2'],
#   's62': ['p65', 'p186', 'p135', 'p111', 'p40'],
#   's63': ['p88', 'p33', 'p87', 'p85', 'p70'],
#   's64': ['p167', 'p71', 'p33', 'p200', 'p47'],
#   's65': ['p23', 'p95', 'p107', 'p103', 'p65'],
#   's66': ['p66', 'p169', 'p199', 'p64', 'p155'],
#   's67': ['p115', 'p117', 'p80', 'p54', 'p181'],
#   's68': ['p92', 'p23', 'p40', 'p130', 'p188'],
#   's69': ['p61', 'p62', 'p93', 'p200', 'p34'],
#   's70': ['p63', 'p40', 'p32', 'p30', 'p90'],
#   's71': ['p150', 'p16', 'p73', 'p24', 'p142'],
#   's72': ['p77', 'p46', 'p108', 'p154', 'p47'],
#   's73': ['p99', 'p174', 'p89', 'p86', 'p79'],
#   's74': ['p47', 'p184', 'p100', 'p14', 'p172'],
#   's75': ['p83', 'p141', 'p184', 'p43', 'p171'],
#   's76': ['p170', 'p146', 'p130', 'p171', 'p17'],
#   's77': ['p42', 'p172', 'p183', 'p194', 'p33'],
#   's78': ['p85', 'p67', 'p19', 'p108', 'p26'],
#   's79': ['p79', 'p66', 'p48', 'p117', 'p91'],
#   's80': ['p42', 'p20', 'p55', 'p34', 'p153'],
#   's81': ['p10', 'p11', 'p53', 'p177', 'p45'],
#   's82': ['p48', 'p141', 'p140', 'p175', 'p147'],
#   's83': ['p17', 'p64', 'p198', 'p164', 'p105'],
#   's84': ['p62', 'p155', 'p137', 'p100', 'p139'],
#   's85': ['p144', 'p123', 'p79', 'p119', 'p162'],
#   's86': ['p90', 'p59', 'p45', 'p51', 'p167'],
#   's87': ['p132', 'p147', 'p71', 'p60', 'p156'],
#   's88': ['p13', 'p185', 'p105', 'p67', 'p17'],
#   's89': ['p164', 'p50', 'p48', 'p178', 'p102'],
#   's90': ['p155', 'p77', 'p189', 'p70', 'p97'],
#   's91': ['p189', 'p87', 'p84', 'p73', 'p38'],
#   's92': ['p96', 'p38', 'p36', 'p116', 'p128'],
#   's93': ['p120', 'p142', 'p138', 'p39', 'p117'],
#   's94': ['p179', 'p147', 'p146', 'p66', 'p200'],
#   's95': ['p15', 'p195', 'p160', 'p30', 'p53'],
#   's96': ['p25', 'p184', 'p37', 'p175', 'p141'],
#   's97': ['p125', 'p165', 'p79', 'p121', 'p200'],
#   's98': ['p118', 'p73', 'p174', 'p159', 'p164'],
#   's99': ['p139', 'p50', 'p110', 'p68', 'p39'],
#   's100': ['p167', 'p32', 'p18', 'p30', 'p157'],
#   's101': ['p157', 'p72', 'p107', 'p69', 'p171'],
#   's102': ['p10', 'p59', 'p26', 'p60', 'p29'],
#   's103': ['p139', 'p88', 'p168', 'p142', 'p163'],
#   's104': ['p116', 'p109', 'p197', 'p22', 'p119'],
#   's105': ['p46', 'p49', 'p180', 'p178', 'p147'],
#   's106': ['p161', 'p141', 'p57', 'p37', 'p125'],
#   's107': ['p108', 'p6', 'p94', 'p118', 'p93'],
#   's108': ['p195', 'p25', 'p173', 'p188', 'p157'],
#   's109': ['p154', 'p93', 'p17', 'p121', 'p153'],
#   's110': ['p150', 'p19', 'p124', 'p166', 'p119'],
#   's111': ['p4', 'p85', 'p56', 'p130', 'p127'],
#   's112': ['p69', 'p193', 'p163', 'p108', 'p22'],
#   's113': ['p45', 'p16', 'p150', 'p44', 'p82'],
#   's114': ['p130', 'p110', 'p167', 'p153', 'p53'],
#   's115': ['p76', 'p104', 'p119', 'p35', 'p87'],
#   's116': ['p118', 'p65', 'p62', 'p149', 'p26'],
#   's117': ['p155', 'p25', 'p84', 'p69', 'p54'],
#   's118': ['p168', 'p167', 'p29', 'p49', 'p4'],
#   's119': ['p196', 'p188', 'p121', 'p181', 'p185'],
#   's120': ['p13', 'p105', 'p20', 'p78', 'p166'],
#   's121': ['p134', 'p87', 'p161', 'p152', 'p58'],
#   's122': ['p81', 'p163', 'p11', 'p184', 'p35'],
#   's123': ['p27', 'p50', 'p34', 'p15', 'p7'],
#   's124': ['p30', 'p76', 'p101', 'p200', 'p14'],
#   's125': ['p186', 'p29', 'p176', 'p197', 'p10'],
#   's126': ['p121', 'p178', 'p21', 'p109', 'p137'],
#   's127': ['p98', 'p14', 'p5', 'p115', 'p164'],
#   's128': ['p33', 'p178', 'p97', 'p57', 'p144'],
#   's129': ['p66', 'p65', 'p122', 'p140', 'p23'],
#   's130': ['p113', 'p120', 'p4', 'p21', 'p199'],
#   's131': ['p45', 'p5', 'p119', 'p197', 'p123'],
#   's132': ['p132', 'p165', 'p116', 'p82', 'p40'],
#   's133': ['p170', 'p111', 'p123', 'p56', 'p18'],
#   's134': ['p163', 'p97', 'p122', 'p77', 'p172'],
#   's135': ['p182', 'p127', 'p83', 'p195', 'p137'],
#   's136': ['p69', 'p59', 'p19', 'p146', 'p131'],
#   's137': ['p6', 'p10', 'p199', 'p89', 'p99'],
#   's138': ['p100', 'p36', 'p109', 'p50', 'p79'],
#   's139': ['p178', 'p158', 'p64', 'p96', 'p102'],
#   's140': ['p13', 'p156', 'p114', 'p151', 'p189'],
#   's141': ['p130', 'p105', 'p2', 'p170', 'p71'],
#   's142': ['p79', 'p3', 'p4', 'p19', 'p188'],
#   's143': ['p143', 'p37', 'p197', 'p115', 'p33'],
#   's144': ['p107', 'p150', 'p69', 'p124', 'p16'],
#   's145': ['p155', 'p99', 'p134', 'p89', 'p12'],
#   's146': ['p22', 'p130', 'p95', 'p134', 'p90'],
#   's147': ['p150', 'p109', 'p87', 'p41', 'p39'],
#   's148': ['p149', 'p184', 'p39', 'p142', 'p120'],
#   's149': ['p198', 'p5', 'p185', 'p138', 'p119'],
#   's150': ['p166', 'p141', 'p18', 'p83', 'p137'],
#   's151': ['p114', 'p50', 'p70', 'p85', 'p4'],
#   's152': ['p76', 'p75', 'p80', 'p102', 'p123'],
#   's153': ['p67', 'p107', 'p103', 'p51', 'p109'],
#   's154': ['p129', 'p81', 'p151', 'p75', 'p59'],
#   's155': ['p87', 'p1', 'p32', 'p14', 'p70'],
#   's156': ['p66', 'p193', 'p135', 'p41', 'p123'],
#   's157': ['p34', 'p12', 'p7', 'p95', 'p195'],
#   's158': ['p89', 'p33', 'p60', 'p174', 'p102'],
#   's159': ['p169', 'p190', 'p48', 'p17', 'p199'],
#   's160': ['p140', 'p12', 'p125', 'p70', 'p133'],
#   's161': ['p96', 'p189', 'p118', 'p92', 'p123'],
#   's162': ['p48', 'p158', 'p45', 'p39', 'p190'],
#   's163': ['p114', 'p170', 'p167', 'p94', 'p56'],
#   's164': ['p101', 'p64', 'p150', 'p5', 'p31'],
#   's165': ['p161', 'p83', 'p3', 'p66', 'p64'],
#   's166': ['p3', 'p97', 'p112', 'p111', 'p16'],
#   's167': ['p128', 'p98', 'p78', 'p147', 'p97'],
#   's168': ['p20', 'p88', 'p21', 'p125', 'p97'],
#   's169': ['p100', 'p4', 'p42', 'p43', 'p5'],
#   's170': ['p154', 'p146', 'p88', 'p96', 'p185'],
#   's171': ['p61', 'p33', 'p189', 'p40', 'p174'],
#   's172': ['p33', 'p77', 'p52', 'p31', 'p75'],
#   's173': ['p17', 'p8', 'p98', 'p4', 'p53'],
#   's174': ['p6', 'p120', 'p133', 'p163', 'p144'],
#   's175': ['p63', 'p196', 'p88', 'p25', 'p19'],
#   's176': ['p75', 'p67', 'p3', 'p69', 'p39'],
#   's177': ['p67', 'p189', 'p132', 'p61', 'p150'],
#   's178': ['p173', 'p106', 'p60', 'p189', 'p41'],
#   's179': ['p162', 'p88', 'p116', 'p85', 'p90'],
#   's180': ['p152', 'p149', 'p57', 'p72', 'p67'],
#   's181': ['p145', 'p170', 'p31', 'p33', 'p50'],
#   's182': ['p118', 'p169', 'p1', 'p130', 'p115'],
#   's183': ['p91', 'p24', 'p154', 'p177', 'p84'],
#   's184': ['p94', 'p65', 'p125', 'p91', 'p115'],
#   's185': ['p168', 'p136', 'p130', 'p18', 'p40'],
#   's186': ['p102', 'p197', 'p153', 'p160', 'p82'],
#   's187': ['p107', 'p199', 'p164', 'p121', 'p33'],
#   's188': ['p115', 'p13', 'p69', 'p33', 'p46'],
#   's189': ['p142', 'p137', 'p73', 'p91', 'p111'],
#   's190': ['p173', 'p52', 'p99', 'p123', 'p180'],
#   's191': ['p194', 'p175', 'p106', 'p160', 'p20'],
#   's192': ['p27', 'p165', 'p8', 'p113', 'p89'],
#   's193': ['p58', 'p11', 'p159', 'p86', 'p99'],
#   's194': ['p117', 'p128', 'p159', 'p64', 'p162'],
#   's195': ['p168', 'p79', 'p198', 'p20', 'p97'],
#   's196': ['p11', 'p199', 'p21', 'p53', 'p94'],
#   's197': ['p104', 'p108', 'p119', 'p46', 'p143'],
#   's198': ['p101', 'p112', 'p181', 'p191', 'p12'],
#   's199': ['p181', 'p111', 'p137', 'p129', 'p22'],
#   's200': ['p149', 'p84', 'p20', 'p21', 'p52']},
#  {'p1': {'max_students': 3, 'assigned_students': ['s54', 's148', 's64']},
#   'p2': {'max_students': 5,
#    'assigned_students': ['s13', 's57', 's10', 's28', 's146']},
#   'p3': {'max_students': 3, 'assigned_students': ['s176', 's142', 's174']},
#   'p4': {'max_students': 3, 'assigned_students': ['s169', 's4', 's136']},
#   'p5': {'max_students': 2, 'assigned_students': ['s6', 's12']},
#   'p6': {'max_students': 4, 'assigned_students': ['s45', 's17', 's23', 's43']},
#   'p7': {'max_students': 3, 'assigned_students': ['s53', 's26', 's123']},
#   'p8': {'max_students': 4, 'assigned_students': ['s89', 's14', 's92', 's85']},
#   'p9': {'max_students': 3, 'assigned_students': ['s73', 's64', 's165']},
#   'p10': {'max_students': 1, 'assigned_students': ['s102']},
#   'p11': {'max_students': 2, 'assigned_students': ['s43', 's89']},
#   'p12': {'max_students': 3, 'assigned_students': ['s157', 's145', 's96']},
#   'p13': {'max_students': 4,
#    'assigned_students': ['s22', 's99', 's25', 's124']},
#   'p14': {'max_students': 1, 'assigned_students': ['s155']},
#   'p15': {'max_students': 5,
#    'assigned_students': ['s30', 's11', 's86', 's177', 's75']},
#   'p16': {'max_students': 3, 'assigned_students': ['s49', 's199', 's66']},
#   'p17': {'max_students': 2, 'assigned_students': ['s41', 's83']},
#   'p18': {'max_students': 2, 'assigned_students': ['s191', 's121']},
#   'p19': {'max_students': 5,
#    'assigned_students': ['s175', 's68', 's156', 's59', 's12']},
#   'p20': {'max_students': 2, 'assigned_students': ['s195', 's20']},
#   'p21': {'max_students': 4,
#    'assigned_students': ['s40', 's168', 's8', 's175']},
#   'p22': {'max_students': 4,
#    'assigned_students': ['s104', 's99', 's183', 's32']},
#   'p23': {'max_students': 1, 'assigned_students': ['s183']},
#   'p24': {'max_students': 1, 'assigned_students': ['s71']},
#   'p25': {'max_students': 1, 'assigned_students': ['s108']},
#   'p26': {'max_students': 1, 'assigned_students': ['s168']},
#   'p27': {'max_students': 4,
#    'assigned_students': ['s55', 's128', 's12', 's33']},
#   'p28': {'max_students': 4,
#    'assigned_students': ['s13', 's117', 's50', 's27']},
#   'p29': {'max_students': 3, 'assigned_students': ['s56', 's163', 's165']},
#   'p30': {'max_students': 4,
#    'assigned_students': ['s124', 's64', 's54', 's13']},
#   'p31': {'max_students': 3, 'assigned_students': ['s52', 's32', 's4']},
#   'p32': {'max_students': 5,
#    'assigned_students': ['s16', 's30', 's59', 's26', 's137']},
#   'p33': {'max_students': 5,
#    'assigned_students': ['s181', 's51', 's2', 's150', 's82']},
#   'p34': {'max_students': 1, 'assigned_students': ['s137']},
#   'p35': {'max_students': 5,
#    'assigned_students': ['s163', 's132', 's15', 's104', 's45']},
#   'p36': {'max_students': 3, 'assigned_students': ['s113', 's76', 's192']},
#   'p37': {'max_students': 1, 'assigned_students': ['s107']},
#   'p38': {'max_students': 5,
#    'assigned_students': ['s27', 's6', 's29', 's76', 's50']},
#   'p39': {'max_students': 5,
#    'assigned_students': ['s162', 's128', 's113', 's184', 's107']},
#   'p40': {'max_students': 2, 'assigned_students': ['s70', 's144']},
#   'p41': {'max_students': 5,
#    'assigned_students': ['s60', 's8', 's131', 's18', 's200']},
#   'p42': {'max_students': 5,
#    'assigned_students': ['s80', 's145', 's73', 's155', 's151']},
#   'p43': {'max_students': 4,
#    'assigned_students': ['s196', 's78', 's57', 's53']},
#   'p44': {'max_students': 4,
#    'assigned_students': ['s116', 's37', 's77', 's8']},
#   'p45': {'max_students': 1, 'assigned_students': ['s7']},
#   'p46': {'max_students': 2, 'assigned_students': ['s188', 's154']},
#   'p47': {'max_students': 4,
#    'assigned_students': ['s64', 's12', 's50', 's126']},
#   'p48': {'max_students': 1, 'assigned_students': ['s89']},
#   'p49': {'max_students': 3, 'assigned_students': ['s176', 's108', 's59']},
#   'p50': {'max_students': 3, 'assigned_students': ['s138', 's199', 's196']},
#   'p51': {'max_students': 5,
#    'assigned_students': ['s35', 's86', 's38', 's120', 's189']},
#   'p52': {'max_students': 2, 'assigned_students': ['s49', 's70']},
#   'p53': {'max_students': 5,
#    'assigned_students': ['s196', 's31', 's81', 's51', 's8']},
#   'p54': {'max_students': 3, 'assigned_students': ['s34', 's117', 's94']},
#   'p55': {'max_students': 5,
#    'assigned_students': ['s186', 's130', 's123', 's145', 's48']},
#   'p56': {'max_students': 3, 'assigned_students': ['s111', 's147', 's192']},
#   'p57': {'max_students': 1, 'assigned_students': ['s163']},
#   'p58': {'max_students': 5,
#    'assigned_students': ['s193', 's19', 's74', 's20', 's112']},
#   'p59': {'max_students': 3, 'assigned_students': ['s156', 's45', 's27']},
#   'p60': {'max_students': 2, 'assigned_students': ['s87', 's186']},
#   'p61': {'max_students': 1, 'assigned_students': ['s59']},
#   'p62': {'max_students': 3, 'assigned_students': ['s33', 's116', 's125']},
#   'p63': {'max_students': 1, 'assigned_students': ['s148']},
#   'p64': {'max_students': 4,
#    'assigned_students': ['s194', 's47', 's139', 's188']},
#   'p65': {'max_students': 3, 'assigned_students': ['s121', 's37', 's86']},
#   'p66': {'max_students': 5,
#    'assigned_students': ['s18', 's165', 's66', 's94', 's128']},
#   'p67': {'max_students': 5,
#    'assigned_students': ['s148', 's21', 's14', 's96', 's50']},
#   'p68': {'max_students': 3, 'assigned_students': ['s89', 's24', 's6']},
#   'p69': {'max_students': 1, 'assigned_students': ['s144']},
#   'p70': {'max_students': 4,
#    'assigned_students': ['s160', 's1', 's120', 's179']},
#   'p71': {'max_students': 5,
#    'assigned_students': ['s141', 's151', 's66', 's87', 's138']},
#   'p72': {'max_students': 2, 'assigned_students': ['s30', 's101']},
#   'p73': {'max_students': 5,
#    'assigned_students': ['s72', 's159', 's102', 's41', 's35']},
#   'p74': {'max_students': 5,
#    'assigned_students': ['s174', 's59', 's158', 's167', 's54']},
#   'p75': {'max_students': 3, 'assigned_students': ['s62', 's41', 's13']},
#   'p76': {'max_students': 1, 'assigned_students': ['s152']},
#   'p77': {'max_students': 4,
#    'assigned_students': ['s72', 's134', 's172', 's177']},
#   'p78': {'max_students': 3, 'assigned_students': ['s2', 's137', 's11']},
#   'p79': {'max_students': 3, 'assigned_students': ['s19', 's162', 's134']},
#   'p80': {'max_students': 3, 'assigned_students': ['s67', 's37', 's178']},
#   'p81': {'max_students': 4,
#    'assigned_students': ['s122', 's61', 's58', 's4']},
#   'p82': {'max_students': 5,
#    'assigned_students': ['s132', 's113', 's133', 's23', 's106']},
#   'p83': {'max_students': 2, 'assigned_students': ['s135', 's150']},
#   'p84': {'max_students': 5,
#    'assigned_students': ['s91', 's183', 's21', 's73', 's142']},
#   'p85': {'max_students': 1, 'assigned_students': ['s78']},
#   'p86': {'max_students': 3, 'assigned_students': ['s124', 's154', 's173']},
#   'p87': {'max_students': 3, 'assigned_students': ['s115', 's63', 's172']},
#   'p88': {'max_students': 2, 'assigned_students': ['s103', 's36']},
#   'p89': {'max_students': 5,
#    'assigned_students': ['s12', 's158', 's39', 's192', 's85']},
#   'p90': {'max_students': 3, 'assigned_students': ['s105', 's87', 's23']},
#   'p91': {'max_students': 1, 'assigned_students': ['s189']},
#   'p92': {'max_students': 5,
#    'assigned_students': ['s4', 's15', 's84', 's177', 's156']},
#   'p93': {'max_students': 5,
#    'assigned_students': ['s109', 's69', 's107', 's4', 's22']},
#   'p94': {'max_students': 2, 'assigned_students': ['s2', 's197']},
#   'p95': {'max_students': 1, 'assigned_students': ['s98']},
#   'p96': {'max_students': 1, 'assigned_students': ['s92']},
#   'p97': {'max_students': 2, 'assigned_students': ['s90', 's113']},
#   'p98': {'max_students': 3, 'assigned_students': ['s173', 's127', 's14']},
#   'p99': {'max_students': 4,
#    'assigned_students': ['s48', 's73', 's185', 's52']},
#   'p100': {'max_students': 3, 'assigned_students': ['s84', 's2', 's22']},
#   'p101': {'max_students': 4,
#    'assigned_students': ['s198', 's164', 's95', 's157']},
#   'p102': {'max_students': 4,
#    'assigned_students': ['s58', 's109', 's184', 's18']},
#   'p103': {'max_students': 5,
#    'assigned_students': ['s65', 's51', 's21', 's23', 's15']},
#   'p104': {'max_students': 3, 'assigned_students': ['s104', 's96', 's195']},
#   'p105': {'max_students': 1, 'assigned_students': ['s120']},
#   'p106': {'max_students': 3, 'assigned_students': ['s49', 's180', 's139']},
#   'p107': {'max_students': 5,
#    'assigned_students': ['s153', 's167', 's177', 's98', 's178']},
#   'p108': {'max_students': 5,
#    'assigned_students': ['s23', 's197', 's160', 's165', 's104']},
#   'p109': {'max_students': 2, 'assigned_students': ['s14', 's147']},
#   'p110': {'max_students': 3, 'assigned_students': ['s99', 's46', 's60']},
#   'p111': {'max_students': 5,
#    'assigned_students': ['s29', 's99', 's41', 's197', 's131']},
#   'p112': {'max_students': 4,
#    'assigned_students': ['s166', 's57', 's136', 's193']},
#   'p113': {'max_students': 1, 'assigned_students': ['s59']},
#   'p114': {'max_students': 4,
#    'assigned_students': ['s151', 's179', 's164', 's10']},
#   'p115': {'max_students': 5,
#    'assigned_students': ['s184', 's19', 's81', 's91', 's23']},
#   'p116': {'max_students': 3, 'assigned_students': ['s151', 's199', 's52']},
#   'p117': {'max_students': 3, 'assigned_students': ['s79', 's169', 's50']},
#   'p118': {'max_students': 4,
#    'assigned_students': ['s11', 's182', 's5', 's131']},
#   'p119': {'max_students': 1, 'assigned_students': ['s25']},
#   'p120': {'max_students': 5,
#    'assigned_students': ['s38', 's57', 's11', 's24', 's177']},
#   'p121': {'max_students': 5,
#    'assigned_students': ['s126', 's159', 's73', 's8', 's118']},
#   'p122': {'max_students': 5,
#    'assigned_students': ['s129', 's28', 's10', 's64', 's42']},
#   'p123': {'max_students': 4,
#    'assigned_students': ['s156', 's133', 's161', 's159']},
#   'p124': {'max_students': 2, 'assigned_students': ['s49', 's199']},
#   'p125': {'max_students': 3, 'assigned_students': ['s1', 's47', 's173']},
#   'p126': {'max_students': 3, 'assigned_students': ['s39', 's64', 's76']},
#   'p127': {'max_students': 5,
#    'assigned_students': ['s143', 's165', 's64', 's3', 's164']},
#   'p128': {'max_students': 2, 'assigned_students': ['s167', 's42']},
#   'p129': {'max_students': 5,
#    'assigned_students': ['s46', 's29', 's13', 's175', 's25']},
#   'p130': {'max_students': 3, 'assigned_students': ['s76', 's146', 's114']},
#   'p131': {'max_students': 1, 'assigned_students': ['s136']},
#   'p132': {'max_students': 3, 'assigned_students': ['s8', 's131', 's96']},
#   'p133': {'max_students': 2, 'assigned_students': ['s18', 's189']},
#   'p134': {'max_students': 4,
#    'assigned_students': ['s49', 's12', 's47', 's158']},
#   'p135': {'max_students': 4,
#    'assigned_students': ['s169', 's95', 's3', 's65']},
#   'p136': {'max_students': 3, 'assigned_students': ['s37', 's185', 's180']},
#   'p137': {'max_students': 3, 'assigned_students': ['s84', 's181', 's98']},
#   'p138': {'max_students': 4,
#    'assigned_students': ['s178', 's177', 's184', 's30']},
#   'p139': {'max_students': 1, 'assigned_students': ['s96']},
#   'p140': {'max_students': 5,
#    'assigned_students': ['s122', 's91', 's7', 's132', 's142']},
#   'p141': {'max_students': 2, 'assigned_students': ['s82', 's106']},
#   'p142': {'max_students': 4,
#    'assigned_students': ['s93', 's68', 's167', 's138']},
#   'p143': {'max_students': 2, 'assigned_students': ['s143', 's30']},
#   'p144': {'max_students': 2, 'assigned_students': ['s174', 's128']},
#   'p145': {'max_students': 2, 'assigned_students': ['s32', 's183']},
#   'p146': {'max_students': 5,
#    'assigned_students': ['s9', 's102', 's97', 's90', 's179']},
#   'p147': {'max_students': 3, 'assigned_students': ['s105', 's191', 's180']},
#   'p148': {'max_students': 2, 'assigned_students': ['s22', 's144']},
#   'p149': {'max_students': 3, 'assigned_students': ['s200', 's180', 's5']},
#   'p150': {'max_students': 1, 'assigned_students': ['s177']},
#   'p151': {'max_students': 4,
#    'assigned_students': ['s154', 's44', 's140', 's77']},
#   'p152': {'max_students': 1, 'assigned_students': ['s121']},
#   'p153': {'max_students': 2, 'assigned_students': ['s147', 's15']},
#   'p154': {'max_students': 2, 'assigned_students': ['s24', 's170']},
#   'p155': {'max_students': 1, 'assigned_students': ['s47']},
#   'p156': {'max_students': 2, 'assigned_students': ['s42', 's28']},
#   'p157': {'max_students': 5,
#    'assigned_students': ['s89', 's182', 's68', 's183', 's130']},
#   'p158': {'max_students': 1, 'assigned_students': ['s93']},
#   'p159': {'max_students': 3, 'assigned_students': ['s143', 's169', 's5']},
#   'p160': {'max_students': 4,
#    'assigned_students': ['s95', 's186', 's26', 's20']},
#   'p161': {'max_students': 3, 'assigned_students': ['s163', 's103', 's97']},
#   'p162': {'max_students': 3, 'assigned_students': ['s179', 's85', 's80']},
#   'p163': {'max_students': 5,
#    'assigned_students': ['s21', 's147', 's163', 's170', 's59']},
#   'p164': {'max_students': 4,
#    'assigned_students': ['s187', 's170', 's128', 's177']},
#   'p165': {'max_students': 5,
#    'assigned_students': ['s97', 's30', 's170', 's142', 's193']},
#   'p166': {'max_students': 4,
#    'assigned_students': ['s10', 's20', 's110', 's178']},
#   'p167': {'max_students': 2, 'assigned_students': ['s163', 's100']},
#   'p168': {'max_students': 1, 'assigned_students': ['s118']},
#   'p169': {'max_students': 2, 'assigned_students': ['s3', 's159']},
#   'p170': {'max_students': 5,
#    'assigned_students': ['s28', 's128', 's196', 's162', 's195']},
#   'p171': {'max_students': 1, 'assigned_students': ['s69']},
#   'p172': {'max_students': 2, 'assigned_students': ['s74', 's109']},
#   'p173': {'max_students': 1, 'assigned_students': ['s190']},
#   'p174': {'max_students': 4,
#    'assigned_students': ['s98', 's171', 's22', 's45']},
#   'p175': {'max_students': 3, 'assigned_students': ['s191', 's57', 's125']},
#   'p176': {'max_students': 4,
#    'assigned_students': ['s2', 's150', 's80', 's10']},
#   'p177': {'max_students': 1, 'assigned_students': ['s57']},
#   'p178': {'max_students': 4,
#    'assigned_students': ['s26', 's86', 's85', 's113']},
#   'p179': {'max_students': 4,
#    'assigned_students': ['s41', 's36', 's59', 's81']},
#   'p180': {'max_students': 1, 'assigned_students': ['s45']},
#   'p181': {'max_students': 4,
#    'assigned_students': ['s199', 's14', 's196', 's112']},
#   'p182': {'max_students': 5,
#    'assigned_students': ['s109', 's94', 's142', 's100', 's59']},
#   'p183': {'max_students': 2, 'assigned_students': ['s17', 's38']},
#   'p184': {'max_students': 5,
#    'assigned_students': ['s148', 's5', 's96', 's75', 's34']},
#   'p185': {'max_students': 4,
#    'assigned_students': ['s149', 's88', 's134', 's144']},
#   'p186': {'max_students': 3, 'assigned_students': ['s62', 's191', 's177']},
#   'p187': {'max_students': 1, 'assigned_students': ['s90']},
#   'p188': {'max_students': 2, 'assigned_students': ['s68', 's95']},
#   'p189': {'max_students': 2, 'assigned_students': ['s178', 's176']},
#   'p190': {'max_students': 5,
#    'assigned_students': ['s74', 's61', 's199', 's159', 's150']},
#   'p191': {'max_students': 1, 'assigned_students': ['s164']},
#   'p192': {'max_students': 5,
#    'assigned_students': ['s200', 's100', 's137', 's145', 's11']},
#   'p193': {'max_students': 2, 'assigned_students': ['s112', 's92']},
#   'p194': {'max_students': 1, 'assigned_students': ['s77']},
#   'p195': {'max_students': 2, 'assigned_students': ['s25', 's173']},
#   'p196': {'max_students': 2, 'assigned_students': ['s119', 's135']},
#   'p197': {'max_students': 3, 'assigned_students': ['s131', 's143', 's125']},
#   'p198': {'max_students': 4,
#    'assigned_students': ['s15', 's186', 's79', 's14']},
#   'p199': {'max_students': 5,
#    'assigned_students': ['s130', 's50', 's137', 's4', 's193']},
#   'p200': {'max_students': 5,
#    'assigned_students': ['s95', 's28', 's188', 's198', 's3']}},
#  ['student_names',
#   '1st_choice',
#   '2st_choice',
#   '3st_choice',
#   '4st_choice',
#   '5st_choice'])
